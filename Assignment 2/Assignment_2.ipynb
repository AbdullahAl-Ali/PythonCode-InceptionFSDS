# %% [markdown]
# # 1. Email Validator (String Filtering + Loops)
# Real-world use: Used in signup forms or data cleaning tasks.
#
# Task:
# Check if a given email is valid — must contain “@” and end with “.com” or “.org”.
#
# Example:
# Input: hello@inceptionbd.com
# Output: Valid Email

# %%
mail = str(input("Enter your email address: "))

if "@" in mail and ".com" or ".org" in mail:
    print("Valid email address.")
else:
    print("Invalid email address, an email must contain '@' and end with '.com' or '.org'.")
# Out:
# Valid email address.

# %% [markdown]
# # 2. Count Word Frequency in Customer Reviews
# Real-world use: Analyzing reviews or comments in text analytics.
#
# Task:
# Given a review text, count how many times each word appears (ignore case).
#
# Example:
# Input: "This product is good and this service is excellent"
# Output: {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}

# %%
text =  input("Enter the review text: ").lower()

words = text.split() 
word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print("Word Frequency: ")
for word, count in word_count.items():
    print(f"{word}: {count}")
# Out:
# Word Frequency:
# hello,: 1
# my: 2
# name: 2
# is: 2
# abdullah,: 1
# and: 1
# abudllah: 1
# said: 1
# soha: 1

# %% [markdown]
# # 3. Password Strength Checker
# Real-world use: Used in user authentication systems.
#
# Task:
# Check if a password is strong — must have at least one uppercase, one lowercase, one digit, and one
# special character.
#
# Example:
# Input: "Hello@123"
# Output: Strong Password

# %%
password = input("Enter your password: ")

has_upper = False
has_lower = False
has_digit = False
has_sp_char = False

for char in password:
    if char.isupper():
        has_upper = True
    elif char.islower():
        has_lower = True
    elif char.isdigit():
        has_digit = True
    elif not char.isalnum():
        has_sp_char = True

if has_upper and has_lower and has_digit and has_sp_char:
    print("Strong Password.")
else:
    print("Password is weak.")
# Out:
# Strong Password.

# %% [markdown]
# # 4. Username Generator (Will Do it later)
# Real-world use: Automatically create usernames for users.
#
# Task:
# Take user’s full name and generate a short username.
# Rules: first 3 letters of first name + last 3 letters of last name + random number (use loops only).
#
# Example:
# Input: "Mamun Malitha"
# Output: mamitha57

# %%
import random
#random_number = random.randint(10, 99)

full_name = input("Enter your full name (first and last): ").lower().strip()
names = full_name.split()  

first_name = names[0]
last_name = names[-1]

first_part = ""
count = 0
for char in first_name:
    if count < 3:
        first_part += char
        count += 1
    else: 
        break

last_part = ""
count = 0
for i in range(len(last_name) -3, len(last_name)):
    if i >= 0:
        last_part += last_name[i]
    else:
        break

num = ""
for i in range(2):
    num += str(random.randint(0,9))

username = first_part + last_part + num
print("Your Auto-genereted Username is :", username)
# Out:
# Your Auto-genareted Username is : abdali78

# %% [markdown]
# # 5. SMS Word Counter
# Real-world use: Used in messaging apps or social media post limit check.
#
# Task: Count how many characters and words are in a message, and tell if it exceeds 160 characters (SMS limit).
#
# Example:
# Input: "This is a demo message."
# Output: Words = 5, Characters = 23, Status = Within Limit

# %%
message = input("Enter the SMS: ")

char_count = len(message)

words = message.split()
word_count = len(words)

if char_count >160:
    status = "Limit Exceeded!"

else:
    status = "Within Limit."

print(f"Words = {word_count}, Characters = {char_count}, Status = {status}")
# Out:
# Words = 5, Characters = 23, Status = Within Limit.

# %% [markdown]
# # 6. Remove Duplicates from Contact List
# Real-world use: Data cleaning in CRM or user databases.
#
# Task: Given a list of names (comma separated), remove duplicates.
#
# Example:
# Input: "Rahim, Karim, Rahim, Sultana"
# Output: "Rahim, Karim, Sultana"

# %%
names = input("Enter names (comma separated): ")

name_list = [n.strip() for n in names.split(",")]

unique = []
for n in name_list:
    if n not in unique:
        unique.append(n)

output = ", ".join(unique)

print(output)
# Out:
# Rahim, Karim, Sultana, Abdullah

# %% [markdown]
# # 7. Detect Suspicious Words in Text (Moderation)
# Real-world use: Used in chat moderation or email filtering.
#
# Task:
# If any “banned” words like ['spam', 'scam', 'fake'] are found in a text, print “Warning”.
#
# Example:
#
# Input: "This is a scam offer"
#
# Output: Warning: Suspicious content detected

# %%
message = input("Enter the text or mail: ").lower()

banned_words = ['spam', 'scam', 'fake']

flag = False

for word in banned_words:
     if word in message:
          flag = True
          break

if flag:
    print("Warning: Suspicious content detected.")

else:
     print("Content is clean.")
# Out:
# Content is clean.

# %% [markdown]
# # 8. Invoice Code Formatter
# Real-world use: Formatting IDs or codes in finance or ERP systems.
#
# Task:
# Given an invoice number like 23, generate code in the format INV00023.
#
# Example:
#
# Input: 23
#
# Output: INV00023

# %%
inv_num = int(input("Enter Invoice Number: "))

formatted_code = f"INV{inv_num:05d}"

#formatted_code = "INV" + ("0" * (5 - len(num))) + num

print(formatted_code)
# Out:
# INV00043

# %% [markdown]
# # 9. Count Hashtags and Mentions (Social Media Analytics)
# Real-world use: Used in analyzing social media posts.
#
# Task:
# Count how many hashtags (#) and mentions (@) appear in a post.
#
# Example:
#
# Input: "Check out #AIWorkshop and follow @inceptionbd"
#
# Output: Hashtags = 1, Mentions = 1

# %%
text = str(input("Copy the post and peste it here: "))

hash_count = text.count("#")
mention_count = text.count("@")

print(f"Hashtags = {hash_count}, Mention = {mention_count}")
# Out:
# Hashtags = 3, Mention = 4

# %% [markdown]
# # 10. Word Reversal for Data Encryption
# Real-world use: Simple text obfuscation or playful encoding.
#
# Task:
# Reverse each word in a sentence while keeping word order the same.
#
# Example:
#
# Input: "AI is fun"
#
#
# Output: "IA si nuf"

# %%
text = str(input("Enter the data to encrypt: "))

words = text.split()
rev_word = []

for word in words:
    rev = "".join(reversed(word)) 
    rev_word.append(rev)

print(" ".join(rev_word))
# Out:
# emocleW ot neg IA
